# %%
# !conda install -c conda-forge ffmpeg -y
# !ffmpeg -version

# %%
# !pip install torch
# Out:
# ...
#   Using cached torch-2.6.0-cp310-cp310-manylinux1_x86_64.whl.metadata (28 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached tiktoken-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# ...
# Using cached tiktoken-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# ...

# %%
import whisper
print(whisper.__version__)
# Out:
# 20240930

# %%
# !pip install setuptools-rust
# Out:
# ...
#   Using cached setuptools_rust-1.11.1-py3-none-any.whl.metadata (9.6 kB)
# ...
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Using cached setuptools_rust-1.11.1-py3-none-any.whl (28 kB)
# Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [setuptools-rust]
# ...

# %%
# !pip install git+https://github.com/openai/whisper.git
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-joacedhs
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-joacedhs
#   Resolved https://github.com/openai/whisper.git to commit dd985ac4b90cafeef8712f2998d62c59c3e62d22
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20240930-py3-none-any.whl size=803707 sha256=748012a77fff6cee4b4d9e54446f2011ad42a39a0752ae87aa76d726d190c15b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8nn9fgmt/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# ...

# %%
# !whisper male_english_output.wav --model tiny
# Out:
# 100%|█████████████████████████████████████| 72.1M/72.1M [00:01<00:00, 61.9MiB/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:03.840]  Hi Team, we are now able to generate speech using fast speech too.

# %%
# !whisper female_english_output.wav --model tiny
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:04.000]  High team, we are now able to generate speech using fast speech too.

# %%
# !whisper male_telugu_output.wav --language te

# %%
import whisper

model = whisper.load_model("large")
result = model.transcribe('whisper/male_telugu_output (1).wav')
print(result["text"])
